# %% [markdown]
# <a href="https://colab.research.google.com/github/fenix1795/Mapasdendidadedu/blob/main/mapa_baseciad_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://contextily.readthedocs.io/en/latest/intro_guide.html#Providers
#codigos para hacermapas base einsertar shape 
#autor: eduardo sanchez carrion

# %%
# !pip install geopandas

# %%
# !pip install contextily
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached contextily-1.3.0-py3-none-any.whl (16 kB)
# ...
#   Using cached mercantile-1.2.1-py3-none-any.whl (14 kB)
# ...
#   Using cached xyzservices-2023.2.0-py3-none-any.whl (55 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 41.4 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt

# %%
import os 
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as cx

# %%
region= gpd.read_file("/content/drive/MyDrive/MODULO 6/SHAPEFILE/SHAFILE DEL PERÚ-MAPA BASE/Regiones")

# %%
ancash= gpd.read_file("/content/drive/MyDrive/MODULO 6/SHAPEFILE/SHAFILE DEL PERÚ-MAPA BASE/Regiones/Carpeta sin título/Untitled Folder")

# %%
ancash1= gpd.read_file("/content/drive/MyDrive/MODULO 6/SHAPEFILE/SHAFILE DEL PERÚ-MAPA BASE/Regiones/Carpeta sin título")

# %%
estaciones= gpd.read_file("/content/drive/MyDrive/MODULO 6/SHAPEFILE/ESTACIONESCIAD2023")

# %%
import geopandas as gpd
from matplotlib import pyplot as plt
import contextily as ctx

# %%
ancash= gpd.read_file("/content/drive/MyDrive/MODULO 6/SHAPEFILE/SHAFILE DEL PERÚ-MAPA BASE/Regiones/Carpeta sin título/Untitled Folder")
ancash_proyectada= ancash.to_crs("EPSG:32718")

# %%
estacionesp= estaciones.to_crs("EPSG:32718")

# %%
import seaborn as sns
from matplotlib.colors import Colormap
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt

# %%
fig, ax=plt.subplots(figsize=(15,12))
#maule= ancash_proyectada[ancash_proyectada["REGION"]=="Maule"].copy()
maule=ancash_proyectada
#fig = plt.figure()
#ax=fig.add_subplot(111)
maule.plot(ax=ax, fc="none",ec="red")

ctx.add_basemap(ax=ax,zoom=8, crs="EPSG:32718", source=ctx.providers.Esri.WorldTerrain)
#plt.scatter(estacionesp.coor_x,estacionesp.coor_y,s=100, alpha=0.6,color="lightblue",marker = r'$\clubsuit$')
estacionesp.plot(markersize=100,ax=ax,alpha=0.6,color="blue",marker = r'$\clubsuit$')
plt.show()

#ctx.providers.NASAGIBS.ModisTerrAOD)
#OpenTopoMap

# %%
fig, ax=plt.subplots(figsize=(10,8))

ancash1.plot(ax=ax,color="red")

plt.scatter(estaciones.coor_x,estaciones.coor_y,s=100, alpha=0.6,color="lightblue",marker = r'$\clubsuit$')

plt.show()

# %%
pip install folium
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import folium as fl
import pandas as pd
from folium.plugins import MiniMap
from folium.plugins import FloatImage

# %%
map_base = fl.Map()
map_base
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = fl.Map(
    location=[-10.015553, -77.235250],
    zoom_start=9,
    tiles='Stamen Terrain'
)

tooltip = 'ESTACIONES CIAD'

fl.Marker([-10.241810, -77.235250], popup='EMA OCROS', tooltip=tooltip).add_to(m)
fl.Marker([-9.115553, -77.29497], popup='EMA POTACA', tooltip=tooltip).add_to(m)
fl.Marker([-10.090990, -77.091030], popup='EMA CHIQUIAN  PRECIPITACION 2 mm', tooltip=tooltip).add_to(m)
fl.Marker([-9.0305950, -77.312960], popup='EMA HUARAZ PRECIPITACION 4 mm', tooltip=tooltip).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
